# %%
import numpy as np
import pandas as pd

# %%
data_files = ['twitter_1050_11','twitter_1051_11','twitter_1053_11','twitter_1054_11',
                'twitter_1055_11','twitter_1056_11','twitter_1057_11','twitter_1058_11',
                'twitter_1059_11', 'twitter_1060_11', 'twitter_1061_11']


df1 = pd.read_csv('twitter_data/'+data_files[0]+'.csv')
df2 = pd.read_csv('twitter_data/'+ data_files[1]+'.csv')
df3 = pd.read_csv('twitter_data/'+ data_files[2]+'.csv')
df4 = pd.read_csv('twitter_data/'+ data_files[3]+'.csv')
df5 = pd.read_csv('twitter_data/'+ data_files[4]+'.csv')
df6 = pd.read_csv('twitter_data/'+ data_files[5]+'.csv')
df7 = pd.read_csv('twitter_data/'+ data_files[6]+'.csv')
df8 = pd.read_csv('twitter_data/'+ data_files[7]+'.csv')
df9 = pd.read_csv('twitter_data/'+ data_files[8]+'.csv', lineterminator="\n")
df10= pd.read_csv('twitter_data/'+ data_files[9]+'.csv')
df11 = pd.read_csv('twitter_data/'+ data_files[10]+'.csv')
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3062: DtypeWarning: Columns (0,1,2,3,4,5,6,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
main_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11], axis =0, ignore_index=True)
main_df = main_df.dropna(subset=['user'])

# %%
df2
# Out:
#                        id                                                url  \
# 0      914189112428699648  https://twitter.com/WomensPowerCen/status/9141...
# 1      914143579483856897  https://twitter.com/WomensPowerCen/status/9141...
# 2      914136402912174080  https://twitter.com/NrIsodera/status/914136402...
# 3      914134852139573248  https://twitter.com/NrIsodera/status/914134852...
# 4      913967030914576384  https://twitter.com/Siliconeer/status/91396703...
# ...                   ...                                                ...
# 47499  914836628757209088  https://twitter.com/WomensPowerCen/status/9148...
# 47500  914803348196311040  https://twitter.com/NrIsodera/status/914803348...
# 47501  914790341647245312  https://twitter.com/WomensPowerCen/status/9147...
# 47502  914613463372193792  https://twitter.com/dalmok/status/914613463372...
# 47503  914519388941946880  https://twitter.com/G_Tello1/status/9145193889...
#
#                             date  \
# ...
